# %%
import pandas as pd
data = pd.read_csv(r"D:\Tel U\Semester 6\Proyek Sains Data\hotels_indonesia.csv")
data
# Out:
#       countyCode  countyName   cityCode    cityName   HotelCode  \
# 0             ID   Indonesia     100110       Ababi     1026153
# 1             ID   Indonesia     100110       Ababi     1026321
# 2             ID   Indonesia     100110       Ababi     1623963
# 3             ID   Indonesia     100110       Ababi     1818307
# 4             ID   Indonesia     100110       Ababi     1930386
# ...          ...         ...        ...         ...         ...
# 14584         ID   Indonesia     142463  Yogyakarta     1691114
# 14585         ID   Indonesia     142463  Yogyakarta     1692888
# 14586         ID   Indonesia     142463  Yogyakarta     1693079
# 14587         ID   Indonesia     142463  Yogyakarta     1695565
# 14588         ID   Indonesia     142463  Yogyakarta     1699175
#
#                           HotelName  HotelRating  \
# 0       Pondok Batur Indah Homestay    ThreeStar
# 1      Tirta Ayu Hotel & Restaurant    ThreeStar
# ...

# %%
data.columns
# Out:
# Index(['countyCode', ' countyName', ' cityCode', ' cityName', ' HotelCode',
#        ' HotelName', ' HotelRating', ' Address', ' Attractions',
#        ' Description', ' FaxNumber', ' HotelFacilities', ' Map',
#        ' PhoneNumber', ' PinCode', ' HotelWebsiteUrl'],
#       dtype='object')

# %%
data = data.drop(columns=[' HotelWebsiteUrl'])
data = data.drop(columns=[' FaxNumber'])
data = data.drop(columns=[' PhoneNumber'])

# %%
data
# Out:
#       countyCode  countyName   cityCode    cityName   HotelCode  \
# 0             ID   Indonesia     100110       Ababi     1026153
# 1             ID   Indonesia     100110       Ababi     1026321
# 2             ID   Indonesia     100110       Ababi     1623963
# 3             ID   Indonesia     100110       Ababi     1818307
# 4             ID   Indonesia     100110       Ababi     1930386
# ...          ...         ...        ...         ...         ...
# 14584         ID   Indonesia     142463  Yogyakarta     1691114
# 14585         ID   Indonesia     142463  Yogyakarta     1692888
# 14586         ID   Indonesia     142463  Yogyakarta     1693079
# 14587         ID   Indonesia     142463  Yogyakarta     1695565
# 14588         ID   Indonesia     142463  Yogyakarta     1699175
#
#                           HotelName  HotelRating  \
# 0       Pondok Batur Indah Homestay    ThreeStar
# 1      Tirta Ayu Hotel & Restaurant    ThreeStar
# ...

# %%
data.isnull().sum()
# Out:
# countyCode             0
#  countyName            0
#  cityCode              0
#  cityName              0
#  HotelCode             0
#  HotelName             0
#  HotelRating           0
#  Address               0
#  Attractions        5619
#  Description         691
#  HotelFacilities     639
#  Map                  16
#  PinCode             337
# dtype: int64

# %%
data = data.dropna()
data
# Out:
#       countyCode  countyName   cityCode    cityName   HotelCode  \
# 0             ID   Indonesia     100110       Ababi     1026153
# 1             ID   Indonesia     100110       Ababi     1026321
# 9             ID   Indonesia     109435       Ambon     1175480
# 10            ID   Indonesia     109435       Ambon     1175678
# 11            ID   Indonesia     109435       Ambon     1198521
# ...          ...         ...        ...         ...         ...
# 14584         ID   Indonesia     142463  Yogyakarta     1691114
# 14585         ID   Indonesia     142463  Yogyakarta     1692888
# 14586         ID   Indonesia     142463  Yogyakarta     1693079
# 14587         ID   Indonesia     142463  Yogyakarta     1695565
# 14588         ID   Indonesia     142463  Yogyakarta     1699175
#
#                                     HotelName  HotelRating  \
# 0                 Pondok Batur Indah Homestay    ThreeStar
# 1                Tirta Ayu Hotel & Restaurant    ThreeStar
# ...

# %%
data[['latitude', 'longitude']] = data[' Map'].str.split('|', expand=True).astype(float)
# Out:
# C:\Users\ikhwa\AppData\Local\Temp\ipykernel_21556\930520757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['latitude', 'longitude']] = data[' Map'].str.split('|', expand=True).astype(float)
# C:\Users\ikhwa\AppData\Local\Temp\ipykernel_21556\930520757.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['latitude', 'longitude']] = data[' Map'].str.split('|', expand=True).astype(float)

# %%
data.isnull().sum()
# Out:
# countyCode          0
#  countyName         0
#  cityCode           0
#  cityName           0
#  HotelCode          0
#  HotelName          0
#  HotelRating        0
#  Address            0
#  Attractions        0
#  Description        0
#  HotelFacilities    0
#  Map                0
#  PinCode            0
# latitude            0
# longitude           0
# dtype: int64
